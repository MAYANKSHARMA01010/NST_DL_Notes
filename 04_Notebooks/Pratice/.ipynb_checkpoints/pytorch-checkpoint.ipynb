# %%
import torch

# %%
x = torch.randn(2, 5, 10)
print(f"Shape {x.shape}")
print(f"Rank {x.ndim}")
# Out:
# Shape torch.Size([2, 5, 10])
# Rank 3

# %%
# torch.*_like having ones, zeros, empty, rand(take float) make repilication in tensor

# %%
# to assign type to while making tensor torch.tensor(value, dtype=torch.) or use .to(dtype=torch.)

# %%
# .abs() make all +ve # .neg() make all +ve to -ve and vice-versa

# %%
# x=torch.randint(size=(), low=, high=, dtype=)

# %%
# x.mean(dim=0) can calulate for that dimension only median, max, min, prod, sum, std, and var

# %%
# torch.matmul() or use @

# %%
# torch.dot()
# .T 
# torch.det() 
# torch.log(k + 1e-7) log with base e
# torch.exp(k) e^k
# torch.sqrt() and torch.sigmoid() and torch.softmax()

# %%
# id() identity/address identifier of the Python object
# for deep copy use .clone()
